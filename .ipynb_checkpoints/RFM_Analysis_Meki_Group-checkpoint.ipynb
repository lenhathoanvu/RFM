# %% [markdown]
# # **RFM (Recency Frequency Monetary) Analysis**

# %% [markdown]
# One of the key strategies for Meki Group in the near future is to improve and enhance the shopping experience for customers, increase the number of new customers, and boost customer retention rates. Therefore, the company wants you to use your analytical skills to calculate and segment new customers and loyal customers based on their purchase history in the provided dataset

# %% [markdown]
#  To segment customers based on their purchase history, we can use the RFM (Recency, Frequency, Monetary) analysis. RFM is a behavioral-based method that categorizes customers into segments. Let’s break down the criteria:
#
# - Recency (R): This represents the time since a customer’s most recent purchase. Customers with a smaller recency value tend to be more active and loyal.
# - Frequency (F): This measures how often a customer makes a purchase within a specific time frame. High-frequency customers are potential repeat buyers.
# - Monetary (M): This reflects the total amount of money a customer has spent on products during a given period. High monetary value indicates important customers.

# %% [markdown]
# ###  Read file

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date, datetime
import datetime as dt
import warnings
from sklearn.cluster import KMeans

# %%
import seaborn as sns
import plotly.express as px
import plotly.io as pio
import plotly.graph_objects as go
pio.templates.default = "plotly_white"

# %%
warnings.filterwarnings("ignore")

# %%
Sales2020 = pd.read_csv('Historical_sales2020.csv')
Sales2021 = pd.read_csv('Historical_sales2021.csv')
Sales2022 = pd.read_csv('Historical_sales2022.csv')

# %% [markdown]
# ### Data cleaning

# %%
Sales2021['unit_price'] = Sales2021['unit_price'].str.replace(',','.').astype(float)
Sales2020['unit_price'] = Sales2020['unit_price'].str.replace(',','.').astype(float)

# %%
# Merge Customer dataset for 3 years
Customer_all = pd.concat([Sales2022, Sales2021, Sales2020], ignore_index=True)
Customer_all.sort_values('customer_id')
Customer_all
# Out:
#         transaction_id transaction_date transaction_time  store_id  staff_id  \
# 0                  390         1/1/2022          7:01:00         5        12
# 1                 1228         1/1/2022          7:02:00         5        30
# 2                 1644         1/1/2022          7:03:00         5        12
# 3                 1338         1/1/2022          7:06:00         5        30
# 4                 2257         1/1/2022          7:06:00         5        30
# ...                ...              ...              ...       ...       ...
# 553310             401       12/29/2020         18:06:35         8        15
# 553311             166       12/31/2020         11:00:02         8        42
# 553312             166       12/31/2020         11:00:02         8        42
# 553313             296       12/31/2020         15:38:10         5        27
# 553314             296       12/31/2020         15:38:10         5        27
#
#         customer_id  product_id  quantity_sold  unit_price promo_item_yn
# 0              5658          22              2        2.00             N
# 1              5197          22              1        2.00             N
# 2              5247          22              2        2.00             N
# 3              5465          32              2        3.00             N
# 4              5627          22              1        2.00             N
# ...             ...         ...            ...         ...           ...
# 553310         8600          87              1        2.10             Y
# 553311         8219          72              1        3.25             Y
# 553312         8219          87              1        2.10             Y
# 553313         6000          87              1        2.10             Y
# 553314         6000          72              1        2.65             Y
#
# [553315 rows x 10 columns]

# %%
Customer_all['transaction_date'] = pd.to_datetime(Customer_all['transaction_date'])

# %%
Customer_all.isnull().sum()
# Out:
# transaction_id      0
# transaction_date    0
# transaction_time    0
# store_id            0
# staff_id            0
# customer_id         0
# product_id          0
# quantity_sold       0
# unit_price          0
# promo_item_yn       0
# dtype: int64

# %%
Customer_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 553315 entries, 0 to 553314
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    553315 non-null  int64
#  1   transaction_date  553315 non-null  datetime64[ns]
#  2   transaction_time  553315 non-null  object
#  3   store_id          553315 non-null  int64
#  4   staff_id          553315 non-null  int64
#  5   customer_id       553315 non-null  int64
#  6   product_id        553315 non-null  int64
#  7   quantity_sold     553315 non-null  int64
#  8   unit_price        553315 non-null  float64
#  9   promo_item_yn     553315 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(6), object(2)
# memory usage: 42.2+ MB

# %%
Customer_all.describe()
# Out:
#        transaction_id       store_id       staff_id    customer_id  \
# count   553315.000000  553315.000000  553315.000000  553315.000000
# mean       846.754487       5.341393      25.322341    4941.774056
# std        849.729672       2.071523      12.441507    3248.569555
# min          1.000000       3.000000       6.000000       1.000000
# 25%        216.000000       3.000000      15.000000    1000.000000
# 50%        457.000000       5.000000      26.000000    5892.000000
# 75%       1358.000000       8.000000      41.000000    8294.000000
# max       4203.000000       8.000000      45.000000    8600.000000
#
#           product_id  quantity_sold     unit_price
# count  553315.000000  553315.000000  553315.000000
# mean       48.072742       1.437331       3.377920
# std        18.064032       0.542233       2.656105
# min         1.000000       1.000000       0.800000
# 25%        34.000000       1.000000       2.500000
# 50%        47.000000       1.000000       3.000000
# 75%        60.000000       2.000000       3.750000
# max        87.000000       8.000000      45.000000

# %% [markdown]
# ##### Quantity sold and unit price can't less than 0

# %%
Customer_all[Customer_all.quantity_sold < 0]
# Out:
# Empty DataFrame
# Columns: [transaction_id, transaction_date, transaction_time, store_id, staff_id, customer_id, product_id, quantity_sold, unit_price, promo_item_yn]
# Index: []

# %%
Customer_all[Customer_all.unit_price < 0]
# Out:
# Empty DataFrame
# Columns: [transaction_id, transaction_date, transaction_time, store_id, staff_id, customer_id, product_id, quantity_sold, unit_price, promo_item_yn]
# Index: []

# %% [markdown]
# #### Remove outlier

# %%
fig, ax = plt.subplots()
ax.boxplot(Customer_all['unit_price'])
plt.show()

# %%
Q1 = np.percentile(Customer_all['unit_price'], 25, method='midpoint')
Q3 = np.percentile(Customer_all['unit_price'], 75, method='midpoint')
IQR = Q3 - Q1
print(IQR)
# Out:
# 1.25

# %%
upper = Q3+1.5*IQR
upper_array = np.array(Customer_all['unit_price'] >= upper)
print("Upper Bound:", upper)
print(upper_array.sum())
 
lower = Q1-1.5*IQR
lower_array = np.array(Customer_all['unit_price'] <= lower)
print("Lower Bound:", lower)
print(lower_array.sum())
# Out:
# Upper Bound: 5.625
# 15416
# Lower Bound: 0.625
# 0

# %%
Customer_all = Customer_all[(Customer_all["unit_price"] > lower) & (Customer_all["unit_price"] < upper)]
Customer_all
# Out:
#         transaction_id transaction_date transaction_time  store_id  staff_id  \
# 0                  390       2022-01-01          7:01:00         5        12
# 1                 1228       2022-01-01          7:02:00         5        30
# 2                 1644       2022-01-01          7:03:00         5        12
# 3                 1338       2022-01-01          7:06:00         5        30
# 4                 2257       2022-01-01          7:06:00         5        30
# ...                ...              ...              ...       ...       ...
# 553310             401       2020-12-29         18:06:35         8        15
# 553311             166       2020-12-31         11:00:02         8        42
# 553312             166       2020-12-31         11:00:02         8        42
# 553313             296       2020-12-31         15:38:10         5        27
# 553314             296       2020-12-31         15:38:10         5        27
#
#         customer_id  product_id  quantity_sold  unit_price promo_item_yn
# 0              5658          22              2        2.00             N
# 1              5197          22              1        2.00             N
# 2              5247          22              2        2.00             N
# 3              5465          32              2        3.00             N
# 4              5627          22              1        2.00             N
# ...             ...         ...            ...         ...           ...
# 553310         8600          87              1        2.10             Y
# 553311         8219          72              1        3.25             Y
# 553312         8219          87              1        2.10             Y
# 553313         6000          87              1        2.10             Y
# 553314         6000          72              1        2.65             Y
#
# [537899 rows x 10 columns]

# %%
fig, ax = plt.subplots()
ax.boxplot(Customer_all['quantity_sold'])
plt.show()

# %%
Q1 = np.percentile(Customer_all['quantity_sold'], 25, method='midpoint')
Q3 = np.percentile(Customer_all['quantity_sold'], 75, method='midpoint')
IQR = Q3 - Q1
print(IQR)
# Out:
# 1.0

# %%
upper = Q3+1.5*IQR
upper_array = np.array(Customer_all['quantity_sold'] >= upper)
print("Upper Bound:", upper)
print(upper_array.sum())
 
lower = Q1-1.5*IQR
lower_array = np.array(Customer_all['quantity_sold'] <= lower)
print("Lower Bound:", lower)
print(lower_array.sum())
# Out:
# Upper Bound: 3.5
# 92
# Lower Bound: -0.5
# 0

# %%
Customer_all = Customer_all[(Customer_all["quantity_sold"] > lower) & (Customer_all["quantity_sold"] < upper)]
Customer_all
# Out:
#         transaction_id transaction_date transaction_time  store_id  staff_id  \
# 0                  390       2022-01-01          7:01:00         5        12
# 1                 1228       2022-01-01          7:02:00         5        30
# 2                 1644       2022-01-01          7:03:00         5        12
# 3                 1338       2022-01-01          7:06:00         5        30
# 4                 2257       2022-01-01          7:06:00         5        30
# ...                ...              ...              ...       ...       ...
# 553310             401       2020-12-29         18:06:35         8        15
# 553311             166       2020-12-31         11:00:02         8        42
# 553312             166       2020-12-31         11:00:02         8        42
# 553313             296       2020-12-31         15:38:10         5        27
# 553314             296       2020-12-31         15:38:10         5        27
#
#         customer_id  product_id  quantity_sold  unit_price promo_item_yn
# 0              5658          22              2        2.00             N
# 1              5197          22              1        2.00             N
# 2              5247          22              2        2.00             N
# 3              5465          32              2        3.00             N
# 4              5627          22              1        2.00             N
# ...             ...         ...            ...         ...           ...
# 553310         8600          87              1        2.10             Y
# 553311         8219          72              1        3.25             Y
# 553312         8219          87              1        2.10             Y
# 553313         6000          87              1        2.10             Y
# 553314         6000          72              1        2.65             Y
#
# [537807 rows x 10 columns]

# %% [markdown]
# ## Recency

# %%
now = dt.date(2022,6,28)
now = pd.to_datetime(now)
now
# Out:
# Timestamp('2022-06-28 00:00:00')

# %%
# Last time the customer Purchase 
Recency = Customer_all.groupby(by='customer_id',as_index=False)['transaction_date'].max()
Recency.columns = ['Customer_id', 'Last_Purchase_Date']

# Convert Last_Purchase_Date to datetime
Recency["Last_Purchase_Date"] = pd.to_datetime(Recency["Last_Purchase_Date"])

#Calculate Recency
Recency['Recency'] = Recency.Last_Purchase_Date.apply(lambda x : (now - x).days)

# %%
Recency
# Out:
#       Customer_id Last_Purchase_Date  Recency
# 0               1         2022-04-29       60
# 1               2         2022-04-26       63
# 2               3         2022-04-24       65
# 3               4         2022-04-26       63
# 4               5         2022-04-29       60
# ...           ...                ...      ...
# 2245         8498         2022-04-27       62
# 2246         8499         2022-04-29       60
# 2247         8500         2022-04-26       63
# 2248         8501         2022-04-28       61
# 2249         8600         2022-04-29       60
#
# [2250 rows x 3 columns]

# %%
Recency.drop(columns=['Last_Purchase_Date'],inplace=True)
Recency.head()
# Out:
#    Customer_id  Recency
# 0            1       60
# 1            2       63
# 2            3       65
# 3            4       63
# 4            5       60

# %% [markdown]
# ## Frequency

# %%
Frequency = Customer_all.copy()
Frequency.drop_duplicates(subset=['customer_id','transaction_id'],keep="first",inplace=True)
Frequency
# Out:
#         transaction_id transaction_date transaction_time  store_id  staff_id  \
# 0                  390       2022-01-01          7:01:00         5        12
# 1                 1228       2022-01-01          7:02:00         5        30
# 2                 1644       2022-01-01          7:03:00         5        12
# 3                 1338       2022-01-01          7:06:00         5        30
# 4                 2257       2022-01-01          7:06:00         5        30
# ...                ...              ...              ...       ...       ...
# 156958            1950       2021-01-17            15:50         8        43
# 186090             547       2021-02-17            10:00         8        44
# 213873            1633       2021-03-17            11:57         8        43
# 245217            1365       2021-04-17             7:16         8        44
# 245685            1474       2021-04-17            10:31         8         6
#
#         customer_id  product_id  quantity_sold  unit_price promo_item_yn
# 0              5658          22              2        2.00             N
# 1              5197          22              1        2.00             N
# 2              5247          22              2        2.00             N
# 3              5465          32              2        3.00             N
# 4              5627          22              1        2.00             N
# ...             ...         ...            ...         ...           ...
# 156958         8482          31              1        2.20             N
# 186090         8114          40              2        3.75             N
# 213873         8074          60              2        3.75             N
# 245217         8405          40              2        3.75             N
# 245685         8166          24              2        3.00             N
#
# [27257 rows x 10 columns]

# %%
Frequency = Frequency.drop_duplicates().groupby(
    by=['customer_id'], as_index=False)['transaction_date'].count()
Frequency.columns = ['Customer_id', 'Frequency']

# %%
Frequency
# Out:
#       Customer_id  Frequency
# 0               1          6
# 1               2         16
# 2               3         13
# 3               4          7
# 4               5          6
# ...           ...        ...
# 2245         8498          7
# 2246         8499         10
# 2247         8500         17
# 2248         8501          6
# 2249         8600       2258
#
# [2250 rows x 2 columns]

# %% [markdown]
# ## Monetary

# %%
# Calculate the revenue of company 
Customer_all['Revenue'] = Customer_all['unit_price'] * Customer_all['quantity_sold']

# %%
Customer_all.head()
# Out:
#    transaction_id transaction_date transaction_time  store_id  staff_id  \
# 0             390       2022-01-01          7:01:00         5        12
# 1            1228       2022-01-01          7:02:00         5        30
# 2            1644       2022-01-01          7:03:00         5        12
# 3            1338       2022-01-01          7:06:00         5        30
# 4            2257       2022-01-01          7:06:00         5        30
#
#    customer_id  product_id  quantity_sold  unit_price promo_item_yn  Revenue
# 0         5658          22              2         2.0             N      4.0
# 1         5197          22              1         2.0             N      2.0
# 2         5247          22              2         2.0             N      4.0
# 3         5465          32              2         3.0             N      6.0
# 4         5627          22              1         2.0             N      2.0

# %%
# Find Revenue from each Customer
Monetary = Customer_all.groupby(by='customer_id', as_index=False)['Revenue'].sum()
Monetary.columns = ['Customer_id', 'Monetary']
Monetary.head()
# Out:
#    Customer_id  Monetary
# 0            1    333.00
# 1            2    913.65
# 2            3   1390.85
# 3            4    314.75
# 4            5    276.00

# %% [markdown]
# ## Merging all three columns in one dataframe

# %%
# Merge Recency with Frequency
RF = Recency.merge(Frequency,left_on='Customer_id',right_on='Customer_id')
RF.head()
# Out:
#    Customer_id  Recency  Frequency
# 0            1       60          6
# 1            2       63         16
# 2            3       65         13
# 3            4       63          7
# 4            5       60          6

# %%
# Merge with Monetary
RFM = RF.merge(Monetary, left_on='Customer_id',right_on='Customer_id')
RFM.set_index('Customer_id',inplace=True)
RFM.head()
# Out:
#              Recency  Frequency  Monetary
# Customer_id
# 1                 60          6    333.00
# 2                 63         16    913.65
# 3                 65         13   1390.85
# 4                 63          7    314.75
# 5                 60          6    276.00

# %% [markdown]
# ## Clustering with K means

# %%
rfm_segmentation = RFM.copy()

# %%
Nc = range(1, 10)
kmeans = [KMeans(n_clusters=i) for i in Nc]
score = [kmeans[i].fit(rfm_segmentation).score(rfm_segmentation) for i in range(len(kmeans))]
plt.plot(Nc,score,marker='*')
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.grid()
plt.title('Elbow Curve')
plt.show()

# %%
# Choose number of clusters is K=3
kmeans = KMeans(n_clusters = 3, random_state=0).fit(rfm_segmentation)

# %%
# add labels after clustering 
rfm_segmentation['cluster'] = kmeans.labels_
rfm_segmentation.head(10)
# Out:
#              Recency  Frequency  Monetary  cluster
# Customer_id
# 1                 60          6    333.00        0
# 2                 63         16    913.65        0
# 3                 65         13   1390.85        0
# 4                 63          7    314.75        0
# 5                 60          6    276.00        0
# 6                 68          9    511.80        0
# 7                 61          9    595.10        0
# 8                 63         10    631.05        0
# 9                 63          9    522.65        0
# 10                60         10    504.20        0

# %%
# Quantity each cluster
rfm_segmentation['cluster'].value_counts()
# Out:
# 0    2247
# 1       2
# 2       1
# Name: cluster, dtype: int64

# %%
sns.boxplot(x='cluster', y='Monetary', data=rfm_segmentation)
# Out:
# <Axes: xlabel='cluster', ylabel='Monetary'>

# %% [markdown]
# - cluster 0 have low Monetary rate which is bad. cluster 2 have highest Montary (money spend) platinum where as cluster 1 have medium level(Gold) and cluster 0 is silver customer.

# %%
sns.boxplot(x='cluster', y='Recency', data=rfm_segmentation)
# Out:
# <Axes: xlabel='cluster', ylabel='Recency'>

# %% [markdown]
# - cluster 0 have high recency rate which is bad. cluster 1 and cluster 2 having low so they are in race of platinum and gold customer.

# %%
sns.boxplot(x='cluster', y='Frequency', data=rfm_segmentation)
# Out:
# <Axes: xlabel='cluster', ylabel='Frequency'>

# %% [markdown]
# - cluster 0 have low frequency rate which is bad. cluster 1 and cluster 2 having high so they are in race of platinum and gold customer.

# %% [markdown]
# ### **Conclusion**
# ---
# 1. Platinum customer - frequent and more revenue generator.
# 2. Gold customer - frequent but less revenue generator.
# 3. silver customer - less frequent and less revenue generator.

# %% [markdown]
# ## Ranking Customer’s based upon their recency, frequency, and monetary score

# %%
# Ranking fine scoring criteria for each RFM value
# Arguments (x = value, p = recency, monetary_value, frequency, d = quartiles dict)

#lower the recency, good for store..
def RScore(x,p,d):
    if x <= d[p][0.25]:
        return 1
    elif x <= d[p][0.50]:
        return 2
    elif x <= d[p][0.75]:
        return 3
    else:
        return 4


# Arguments (x = value, p = recency, monetary_value, frequency, k = quartiles dict)

#higher value of frequency and monetary lead to a good consumer. here higher value = 1 in reverse way.

def FMScore(x,p,d):
    if x <= d[p][0.25]:
        return 4
    elif x <= d[p][0.50]:
        return 3
    elif x <= d[p][0.75]:
        return 2
    else:
        return 1

# %%
# Calculate RFM scores
quantile = RFM.quantile(q=[0.25,0.5,0.75])
quantile
# Out:
#       Recency  Frequency  Monetary
# 0.25     61.0        6.0  353.3125
# 0.50     62.0        8.0  498.4500
# 0.75     65.0       11.0  670.0125

# %%
# Convert RFM scores to numeric type
rfm_segmentation['R_Quartile'] = rfm_segmentation['Recency'].apply(RScore,args=('Recency',quantile))
rfm_segmentation['F_Quartile'] = rfm_segmentation['Frequency'].apply(FMScore, args=('Frequency',quantile))
rfm_segmentation['M_Quartile'] = rfm_segmentation['Monetary'].apply(FMScore, args=('Monetary',quantile))
rfm_segmentation.head()
# Out:
#              Recency  Frequency  Monetary  cluster  R_Quartile  F_Quartile  \
# Customer_id
# 1                 60          6    333.00        0           1           4
# 2                 63         16    913.65        0           3           1
# 3                 65         13   1390.85        0           3           1
# 4                 63          7    314.75        0           3           3
# 5                 60          6    276.00        0           1           4
#
#              M_Quartile
# Customer_id
# 1                     4
# 2                     1
# 3                     1
# 4                     4
# 5                     4

# %%
quantile.to_dict()
# Out:
# {'Recency': {0.25: 61.0, 0.5: 62.0, 0.75: 65.0},
#  'Frequency': {0.25: 6.0, 0.5: 8.0, 0.75: 11.0},
#  'Monetary': {0.25: 353.3125, 0.5: 498.45, 0.75: 670.0125}}

# %%
#calculate RFM score

rfm_segmentation['RFMScore'] = rfm_segmentation.R_Quartile.map(str) \
                            + rfm_segmentation.F_Quartile.map(str) \
                            + rfm_segmentation.M_Quartile.map(str)
rfm_segmentation.head()
# Out:
#              Recency  Frequency  Monetary  cluster  R_Quartile  F_Quartile  \
# Customer_id
# 1                 60          6    333.00        0           1           4
# 2                 63         16    913.65        0           3           1
# 3                 65         13   1390.85        0           3           1
# 4                 63          7    314.75        0           3           3
# 5                 60          6    276.00        0           1           4
#
#              M_Quartile RFMScore
# Customer_id
# 1                     4      144
# 2                     1      311
# 3                     1      311
# 4                     4      334
# 5                     4      144

# %%
rfm_segmentation['Total_score'] = rfm_segmentation['R_Quartile'] + \
                                rfm_segmentation['F_Quartile'] + \
                                rfm_segmentation['M_Quartile']

rfm_segmentation.head()
# Out:
#              Recency  Frequency  Monetary  cluster  R_Quartile  F_Quartile  \
# Customer_id
# 1                 60          6    333.00        0           1           4
# 2                 63         16    913.65        0           3           1
# 3                 65         13   1390.85        0           3           1
# 4                 63          7    314.75        0           3           3
# 5                 60          6    276.00        0           1           4
#
#              M_Quartile RFMScore  Total_score
# Customer_id
# 1                     4      144            9
# 2                     1      311            5
# 3                     1      311            5
# 4                     4      334           10
# 5                     4      144            9

# %%
print("Best Customers: ",len(rfm_segmentation[rfm_segmentation['RFMScore']=='111']))
print('Loyal Customers: ',len(rfm_segmentation[rfm_segmentation['F_Quartile']==1]))
print("Big Spenders: ",len(rfm_segmentation[rfm_segmentation['M_Quartile']==1]))
print('Almost Lost: ', len(rfm_segmentation[rfm_segmentation['RFMScore']=='134']))
print('Lost Customers: ',len(rfm_segmentation[rfm_segmentation['RFMScore']=='344']))
print('Lost Cheap Customers: ',len(rfm_segmentation[rfm_segmentation['RFMScore']=='444']))
# Out:
# Best Customers:  207
# Loyal Customers:  474
# Big Spenders:  563
# Almost Lost:  23
# Lost Customers:  76
# Lost Cheap Customers:  222

# %%
categories = ['Best Customers', 'Loyal Customers', 'Big Spenders', 'Almost Lost', 'Lost Customers', 'Lost Cheap Customers']
quantities = [207, 474, 563, 23, 76, 222]

# %%
colors = ['#FF9999', '#66B3FF', '#99FF99', '#FFCC99', '#FFD700', '#C71585']

# Create the bar chart
plt.figure(figsize=(10, 6))
bars = plt.bar(categories, quantities, color= colors)

# Add titles and labels
plt.title('Customer Segmentation')
plt.xlabel('Customer Segments')
plt.ylabel('Quantity')
plt.xticks(rotation=45)

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval, int(yval), va='bottom')
    
# Display the bar chart
plt.show()

# %% [markdown]
# ### Some strategic development directions for the store:
#
# __Enhance Loyal Customer Care:__
#
# - Reward Programs: Develop reward programs, discounts, or special offers exclusively for loyal customers to increase engagement.
# - Personalized Services: Provide personalized services, such as sending birthday wishes or special gifts on significant occasions.
#
# __Attract High-Spending Customers:__
#
# - Exclusive Offers: Provide exclusive offers and VIP customer programs for high-spending groups.
# - Premium Products/Services: Introduce additional premium products or services to meet the needs of this customer group.
#
# __Recover Nearly Lost Customers:__
#
# - Feedback Surveys: Send feedback surveys to understand why customers almost left and improve weak points.
# - Promotional Campaigns: Implement promotional campaigns aimed at enticing them to return, such as discounts or gifts when they shop again.
#
# __Reduce Customer Attrition:__
#
# - Analyze Reasons: Analyze the reasons for customer attrition and take measures to address them, such as improving product or service quality.
# - Promotional Programs: Create attractive promotional programs to retain customers.
#
# __Optimize Best Customer Care:__
#
# - Priority Services: Provide priority and special services for the best customer group to enhance satisfaction and loyalty.
# - Loyalty Programs: Ensure this customer group always benefits from loyalty programs and feels valued.
#
# __Marketing Strategy for Potential Customers:__
#
# - Marketing Campaigns: Build marketing campaigns targeting potential customers based on the profile of current customers.
# - Targeted Advertising: Use targeted advertising on online platforms to reach potential customer groups.
#
# __Improve Overall Customer Experience:__
#
# - Employee Training: Enhance employee training on customer service to ensure every customer has the best experience when visiting the store.
# - Service Improvement: Continuously improve service and product quality based on customer feedback.

# %%
rfm_segmentation.sort_values(by=['RFMScore', 'Monetary'], ascending=[True, False])
# Out:
#              Recency  Frequency   Monetary  cluster  R_Quartile  F_Quartile  \
# Customer_id
# 8600              60       2258  416881.00        2           1           1
# 1000              60       3444  379017.45        1           1           1
# 8285              60         25    1564.95        0           1           1
# 8297              60         23    1495.15        0           1           1
# 8384              60         23    1488.90        0           1           1
# ...              ...        ...        ...      ...         ...         ...
# 17                70          1      65.10        0           4           4
# 5813              78          2      64.00        0           4           4
# 359               86          1      55.00        0           4           4
# 5147              84          1      36.00        0           4           4
# 427               85          1      28.00        0           4           4
#
#              M_Quartile RFMScore  Total_score
# Customer_id
# 8600                  1      111            3
# 1000                  1      111            3
# 8285                  1      111            3
# 8297                  1      111            3
# 8384                  1      111            3
# ...                 ...      ...          ...
# 17                    4      444           12
# 5813                  4      444           12
# 359                   4      444           12
# 5147                  4      444           12
# 427                   4      444           12
#
# [2250 rows x 9 columns]

# %%
rfm_segmentation.groupby('Total_score')['Monetary'].mean().plot(kind='bar', colormap='viridis_r')

plt.title('Average money value of each RFM group')
# Out:
# Text(0.5, 1.0, 'Average money value of each RFM group')

# %% [markdown]
# __Based on Monetary we see Total_score 3,4,5 have highest value which is good for model. because it could have combination of values such as 111, 121, 122__

# %%
rfm_segmentation.groupby('Total_score')['Frequency'].mean().plot(kind='bar', colormap='coolwarm')

plt.title('Average Frequency value of each RFM group')
# Out:
# Text(0.5, 1.0, 'Average Frequency value of each RFM group')

# %% [markdown]
# __Based on Frequncy we see Total_score 3,4,5 have highest value which is good for model. because it could have
# combination of values such as 111, 121, 122__

# %%
rfm_segmentation.groupby('Total_score')['Recency'].mean().plot(kind='bar', colormap='bwr_r')

plt.title('Average Recency value of each RFM group')
# Out:
# Text(0.5, 1.0, 'Average Recency value of each RFM group')

# %% [markdown]
# __Based on Recency we see Total_score 10,11,12 have highest value which is good for model. because it could have
# combination of values such as 444, 434, 334 etc__
